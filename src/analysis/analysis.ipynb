# %%
import pandas as pd
import matplotlib.pyplot as plt

# S3から取得したCSVデータの読み込み
df = pd.read_csv('nba_metrics.csv')

# 描画スタイルの設定とサブプロットの初期化
plt.style.use('ggplot')
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# グラフ1: エンゲージメント率上位10件の抽出と描画（棒グラフ）
top_10 = df.sort_values('engagement_rate', ascending=False).head(10)

ax1.bar(top_10.index.astype(str), top_10['engagement_rate'], color='royalblue')
ax1.set_title('Top 10: Engagement Rate (%)', fontsize=14, fontweight='bold')
ax1.set_xlabel('Video ID')
ax1.set_ylabel('Engagement Rate (%)')

# グラフ2: 再生数とエンゲージメント率の相関（散布図）
ax2.scatter(df['playCount'], df['engagement_rate'], color='darkorange', alpha=0.7, s=100)
ax2.set_title('Play Count vs Engagement Rate', fontsize=14, fontweight='bold')
ax2.set_xlabel('Play Count (Views)')
ax2.set_ylabel('Engagement Rate (%)')

# レイアウトの最適化と描画の実行
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-fcac55675d83> in <module>
#       3
#       4 # S3から取得したCSVデータの読み込み
# ----> 5 df = pd.read_csv('nba_metrics.csv')
#       6
#       7 # 描画スタイルの設定とサブプロットの初期化
#
# c:\Users\koki\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# c:\Users\koki\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# c:\Users\koki\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# c:\Users\koki\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# c:\Users\koki\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File nba_metrics.csv does not exist: 'nba_metrics.csv'
